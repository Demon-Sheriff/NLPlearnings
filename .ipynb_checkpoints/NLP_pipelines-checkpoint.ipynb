# %%
# below are some screenshots to refer for NLP pipelines workflow

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# # NLP Pipelines

# %%
img = mpimg.imread('Screenshot from 2024-05-13 12-32-44.png')
plt.imshow(img)
plt.axis('off')  # Optional: turn off axis
plt.show()

# %%
img = mpimg.imread('Screenshot from 2024-05-13 12-35-38.png')
plt.imshow(img)
plt.axis('off')  # Optional: turn off axis
plt.show()

# %%
img = mpimg.imread('Screenshot from 2024-05-13 12-38-52.png')
plt.imshow(img)
plt.axis('off')  # Optional: turn off axis
plt.show()

# %%
img = mpimg.imread('Screenshot from 2024-05-13 12-50-13.png')
plt.imshow(img)
plt.axis('off')  # Optional: turn off axis
plt.show()

# %%
img = mpimg.imread('Screenshot from 2024-05-13 12-53-49.png')
plt.imshow(img)
plt.axis('off')  # Optional: turn off axis
plt.show()
