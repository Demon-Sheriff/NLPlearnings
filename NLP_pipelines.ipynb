# %%
# below are some screenshots to refer for NLP pipelines workflow

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# # NLP Pipelines

# %%
img = mpimg.imread('Screenshot from 2024-05-13 12-32-44.png')
plt.imshow(img)
plt.axis('off')  # Optional: turn off axis
plt.show()

# %% [markdown]
# ![Screenshot%20from%202024-05-13%2012-35-38.png](attachment:Screenshot%20from%202024-05-13%2012-35-38.png)

# %% [markdown]
# ![Screenshot%20from%202024-05-13%2012-38-52.png](attachment:Screenshot%20from%202024-05-13%2012-38-52.png)

# %% [markdown]
# ![Screenshot%20from%202024-05-13%2013-27-15.png](attachment:Screenshot%20from%202024-05-13%2013-27-15.png)

# %% [markdown]
# ![Screenshot%20from%202024-05-13%2013-35-21.png](attachment:Screenshot%20from%202024-05-13%2013-35-21.png)
